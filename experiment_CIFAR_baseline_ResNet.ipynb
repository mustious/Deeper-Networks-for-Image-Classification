# %%
# required google colab installations
# !pip install torchinfo tqdm torchmetrics wandb mlxtend==0.22
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchinfo
#   Downloading torchinfo-1.7.2-py3-none-any.whl (22 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.65.0)
# Collecting torchmetrics
#   Downloading torchmetrics-0.11.4-py3-none-any.whl (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.2/519.2 kB 30.8 MB/s eta 0:00:00
# Collecting wandb
#   Downloading wandb-0.15.2-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 54.5 MB/s eta 0:00:00
# Collecting mlxtend==0.22
#   Downloading mlxtend-0.22.0-py2.py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 54.6 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.2.1 in /usr/local/lib/python3.10/dist-packages (from mlxtend==0.22) (1.10.1)
# Requirement already satisfied: numpy>=1.16.2 in /usr/local/lib/python3.10/dist-packages (from mlxtend==0.22) (1.22.4)
# Requirement already satisfied: pandas>=0.24.2 in /usr/local/lib/python3.10/dist-packages (from mlxtend==0.22) (1.5.3)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from mlxtend==0.22) (1.2.2)
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from mlxtend==0.22) (3.7.1)
# Requirement already satisfied: joblib>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from mlxtend==0.22) (1.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from mlxtend==0.22) (67.7.2)
# Requirement already satisfied: torch>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (2.0.0+cu118)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from torchmetrics) (23.1)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (8.1.3)
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb)
#   Downloading GitPython-3.1.31-py3-none-any.whl (184 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (2.27.1)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (5.9.5)
# Collecting sentry-sdk>=1.0.0 (from wandb)
#   Downloading sentry_sdk-1.22.2-py2.py3-none-any.whl (203 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.3/203.3 kB 11.4 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0 (from wandb)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from wandb) (6.0)
# Collecting pathtools (from wandb)
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting setproctitle (from wandb)
#   Downloading setproctitle-1.3.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.20.3)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend==0.22) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend==0.22) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend==0.22) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend==0.22) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend==0.22) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend==0.22) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend==0.22) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.2->mlxtend==0.22) (2022.7.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (3.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->mlxtend==0.22) (3.1.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (3.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.1->torchmetrics) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.8.1->torchmetrics) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.8.1->torchmetrics) (16.0.3)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.1->torchmetrics) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.1->torchmetrics) (1.3.0)
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8791 sha256=9bc55778aa948ec0607399f49acf9eaf137c32622bd31095b46156dbb24b85f3
#   Stored in directory: /root/.cache/pip/wheels/e7/f3/22/152153d6eb222ee7a56ff8617d80ee5207207a8c00a7aab794
# Successfully built pathtools
# Installing collected packages: pathtools, torchinfo, smmap, setproctitle, sentry-sdk, docker-pycreds, gitdb, mlxtend, GitPython, wandb, torchmetrics
#   Attempting uninstall: mlxtend
#     Found existing installation: mlxtend 0.14.0
#     Uninstalling mlxtend-0.14.0:
#       Successfully uninstalled mlxtend-0.14.0
# Successfully installed GitPython-3.1.31 docker-pycreds-0.4.0 gitdb-4.0.10 mlxtend-0.22.0 pathtools-0.1.2 sentry-sdk-1.22.2 setproctitle-1.3.2 smmap-5.0.0 torchinfo-1.7.2 torchmetrics-0.11.4 wandb-0.15.2

# %%
# import libraries
import random
import math
from pathlib import Path
import sys

from tqdm.auto import tqdm


import numpy as np
import matplotlib.pyplot as plt
from mlxtend.plotting import plot_confusion_matrix

import torchinfo # show model summary

# helper functions 
#from helpers import display_images

# pytorch modules
import torch
from torch.utils.data import DataLoader

# torch vision modules
import torchvision
from torchvision import datasets
from torchvision import transforms
from torch import nn

# metrics module
import torchmetrics

# tracking metrics
import wandb

# %% [markdown]
# ##### Hyper-parameter Initialisations

# %%
config = dict(
    epochs=30,
    learning_rate=1e-1,
    batch_size= 64,
    optimiser="SGD",
    dataset="CIFAR",
    architecture="ResNet-18",
)

# %%
run_name = f"{config['architecture']}_{config['optimiser']}_{config['learning_rate']}_{config['batch_size']}_{config['dataset']}"
print(run_name)
# Out:
# ResNet-18_SGD_0.1_32_CIFAR

# %%
# initialise wandb project
wandb.init(project="ECS795P_CIFAR", config=config, name=run_name)
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.15.2
# Run data is saved locally in <code>/content/wandb/run-20230511_203121-lpzn8k6v</code>
# Syncing run <strong><a href='https://wandb.ai/mustious/ECS795P_CIFAR/runs/lpzn8k6v' target="_blank">ResNet-18_SGD_0.1_32_CIFAR</a></strong> to <a href='https://wandb.ai/mustious/ECS795P_CIFAR' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/mustious/ECS795P_CIFAR' target="_blank">https://wandb.ai/mustious/ECS795P_CIFAR</a>
#  View run at <a href='https://wandb.ai/mustious/ECS795P_CIFAR/runs/lpzn8k6v' target="_blank">https://wandb.ai/mustious/ECS795P_CIFAR/runs/lpzn8k6v</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/mustious/ECS795P_CIFAR/runs/lpzn8k6v?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
config = wandb.config
print(f"Hyper-parameter configurations: \n{config}")
# Out:
# Hyper-parameter configurations:
# {'epochs': 30, 'learning_rate': 0.1, 'batch_size': 32, 'optimiser': 'SGD', 'dataset': 'CIFAR', 'architecture': 'ResNet-18'}

# %%
def display_images(image_dataloader: DataLoader, class_labels, n_rows: int =3, n_cols:int =5, figsize: tuple =(12,6)):

    """
    displays images from dataloader
    """
    # display data sample images
    #n_rows, n_cols = 3, 5
    n_samples = n_rows * n_cols # number sample images to display

    data, label = next(iter(image_dataloader))
    fig, axs = plt.subplots(nrows=n_rows, ncols=n_cols, figsize=figsize)

    for i, image in enumerate(data[:n_samples]):
        image = image.detach()[0]
        #image = image.squeeze(dim=0)
        axs[i%n_rows, i//n_rows].imshow(image.numpy(), cmap="gray")
        axs[i%n_rows, i//n_rows].set(xticks=[], yticks=[])
        axs[i%n_rows, i//n_rows].set_title(class_labels[label[i]])
        
    return fig

# %%
def display_predicted_images(model, image_dataloader: DataLoader, class_labels, n_rows: int =3, n_cols:int =5, figsize: tuple =(12,6)):

    """
    displays images from dataloader
    """
    # display data sample images
    n_samples = n_rows * n_cols # number sample images to display

    data, label = next(iter(image_dataloader))

    model = model.to("cpu")

    model.eval()
    with torch.inference_mode():
        model_predictions_logits = model(data)
        predictions = nn.functional.softmax(model_predictions_logits, dim=0).argmax(dim=1)

    fig, axs = plt.subplots(nrows=n_rows, ncols=n_cols, figsize=figsize)

    for i, image in enumerate(data[:n_samples]):
        image = image.detach()[0]
        #image = image.squeeze(dim=0)
        axs[i%n_rows, i//n_rows].imshow(image.numpy(), cmap="gray")
        axs[i%n_rows, i//n_rows].set(xticks=[], yticks=[])
        title = f"Actual Class {class_labels[label[i]]}\n Predicted Class: {class_labels[predictions[i]]}"
        axs[i%n_rows, i//n_rows].set_title(title)

    return fig

# %%
# device agnostic code
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Current hardware device: {DEVICE}")
# Out:
# Current hardware device: cuda

# %% [markdown]
# #### Downloading and Loading Datasets

# %%
# load CIFAR10 datasets
# CIFAR10 train data
train_data = datasets.CIFAR10(
    root="cifar_data",
    train=True,
    transform=transforms.ToTensor(),
    download=True,
)

# CIFAR10 test data
test_data = datasets.CIFAR10(
    root="cifar_data",
    transform=transforms.ToTensor(),
    train=False,
    download=True,
)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to cifar_data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:13<00:00, 12915462.56it/s]
# Extracting cifar_data/cifar-10-python.tar.gz to cifar_data
# Files already downloaded and verified

# %%
print(f"Train data size: {len(train_data)}")
print(f"Test data size: {len(test_data)}")
print(f"Image size: {np.array(train_data[0][0].shape)}")
# Out:
# Train data size: 50000
# Test data size: 10000
# Image size: [ 3 32 32]

# %%
class_labels = train_data.classes # images class labels
print(f"class labels: {class_labels}")
# Out:
# class labels: ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# train dataloader iterable
train_dataloader = DataLoader(
    dataset=train_data,
    batch_size=config.batch_size,
    shuffle=True
)

# test dataloader iterable
test_dataloader= DataLoader(
    dataset=test_data,
    batch_size=config.batch_size,
)

# %%
display_images(train_dataloader, class_labels=class_labels, n_cols=4, n_rows=3, figsize=(8,6))
plt.show()

# %%
# calculate train and test dataset means and standard deviations
train_data_mean = train_data.data.mean(axis=(0,1,2))/225
train_data_std = train_data.data.std(axis=(0,1,2))/225
test_data_mean = test_data.data.mean(axis=(0,1,2))/225
test_data_std = test_data.data.std(axis=(0,1,2))/225

print(f"Train data mean: {train_data_mean}\t Train data standard deviation: {train_data_std}")
print(f"test data mean: {test_data_mean}\t Test data standard deviation: {test_data_std}")
# Out:
# Train data mean: [0.55691964 0.5464462  0.50606837]	 Train data standard deviation: [0.27996986 0.27594981 0.29646622]
# test data mean: [0.56010952 0.54981557 0.51046364]	 Test data standard deviation: [0.27953952 0.2752779  0.29647136]

# %%
# Train dataset Transforms
train_tranforms = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomRotation(degrees=(0, 180)),
    transforms.RandomHorizontalFlip(0.3),
    transforms.ToTensor(),
    transforms.Normalize(train_data_mean, train_data_std)
    ])

# Test dataset Transforms
test_tranforms = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(test_data_mean, train_data_std)
    ])

# %%
# CIFAR train data with transforms
train_data = datasets.CIFAR10(
    root="cifar_data",
    train=True,
    transform=train_tranforms,
    download=True,
)

# CIFAR test data with transforms
test_data = datasets.CIFAR10(
    root="cifar_data",
    train=False,
    transform=test_tranforms,
    download=True,
)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# train dataloader iterable
train_dataloader = DataLoader(
    dataset=train_data,
    batch_size=config.batch_size,
    shuffle=True
)

# test dataloader iterable
test_dataloader= DataLoader(
    dataset=test_data,
    batch_size=config.batch_size,
)

# %% [markdown]
# #### ResNet-18 Baseline Model

# %%
resnet_model = torchvision.models.resnet18()

# %%
# set the output of the FC layers to number of classes of CIFAR

resnet_fc = nn.Linear(in_features=512, out_features=len(class_labels), bias=True)
resnet_model.fc = resnet_fc

# %%
# display model architecture
torchinfo.summary(resnet_model,
                  input_size=(32, 3, 224, 224), 
                  col_names=["input_size", "output_size", "num_params", "trainable"],
                  col_width=60,
                  row_settings=["var_names"]
                  )
# Out:
# /usr/local/lib/python3.10/dist-packages/torchinfo/torchinfo.py:477: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   action_fn=lambda data: sys.getsizeof(data.storage()),
# /usr/local/lib/python3.10/dist-packages/torch/storage.py:665: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return super().__sizeof__() + self.nbytes()
# ========================================================================================================================================================================================================================================================================================
# Layer (type (var_name))                  Input Shape                                                  Output Shape                                                 Param #                                                      Trainable
# ========================================================================================================================================================================================================================================================================================
# ResNet (ResNet)                          [32, 3, 224, 224]                                            [32, 10]                                                     --                                                           True
# ├─Conv2d (conv1)                         [32, 3, 224, 224]                                            [32, 64, 112, 112]                                           9,408                                                        True
# ├─BatchNorm2d (bn1)                      [32, 64, 112, 112]                                           [32, 64, 112, 112]                                           128                                                          True
# ├─ReLU (relu)                            [32, 64, 112, 112]                                           [32, 64, 112, 112]                                           --                                                           --
# ├─MaxPool2d (maxpool)                    [32, 64, 112, 112]                                           [32, 64, 56, 56]                                             --                                                           --
# ├─Sequential (layer1)                    [32, 64, 56, 56]                                             [32, 64, 56, 56]                                             --                                                           True
# │    └─BasicBlock (0)                    [32, 64, 56, 56]                                             [32, 64, 56, 56]                                             --                                                           True
# │    │    └─Conv2d (conv1)               [32, 64, 56, 56]                                             [32, 64, 56, 56]                                             36,864                                                       True
# │    │    └─BatchNorm2d (bn1)            [32, 64, 56, 56]                                             [32, 64, 56, 56]                                             128                                                          True
# │    │    └─ReLU (relu)                  [32, 64, 56, 56]                                             [32, 64, 56, 56]                                             --                                                           --
# │    │    └─Conv2d (conv2)               [32, 64, 56, 56]                                             [32, 64, 56, 56]                                             36,864                                                       True
# │    │    └─BatchNorm2d (bn2)            [32, 64, 56, 56]                                             [32, 64, 56, 56]                                             128                                                          True
# │    │    └─ReLU (relu)                  [32, 64, 56, 56]                                             [32, 64, 56, 56]                                             --                                                           --
# │    └─BasicBlock (1)                    [32, 64, 56, 56]                                             [32, 64, 56, 56]                                             --                                                           True
# │    │    └─Conv2d (conv1)               [32, 64, 56, 56]                                             [32, 64, 56, 56]                                             36,864                                                       True
# │    │    └─BatchNorm2d (bn1)            [32, 64, 56, 56]                                             [32, 64, 56, 56]                                             128                                                          True
# │    │    └─ReLU (relu)                  [32, 64, 56, 56]                                             [32, 64, 56, 56]                                             --                                                           --
# │    │    └─Conv2d (conv2)               [32, 64, 56, 56]                                             [32, 64, 56, 56]                                             36,864                                                       True
# │    │    └─BatchNorm2d (bn2)            [32, 64, 56, 56]                                             [32, 64, 56, 56]                                             128                                                          True
# │    │    └─ReLU (relu)                  [32, 64, 56, 56]                                             [32, 64, 56, 56]                                             --                                                           --
# ├─Sequential (layer2)                    [32, 64, 56, 56]                                             [32, 128, 28, 28]                                            --                                                           True
# │    └─BasicBlock (0)                    [32, 64, 56, 56]                                             [32, 128, 28, 28]                                            --                                                           True
# │    │    └─Conv2d (conv1)               [32, 64, 56, 56]                                             [32, 128, 28, 28]                                            73,728                                                       True
# │    │    └─BatchNorm2d (bn1)            [32, 128, 28, 28]                                            [32, 128, 28, 28]                                            256                                                          True
# │    │    └─ReLU (relu)                  [32, 128, 28, 28]                                            [32, 128, 28, 28]                                            --                                                           --
# │    │    └─Conv2d (conv2)               [32, 128, 28, 28]                                            [32, 128, 28, 28]                                            147,456                                                      True
# │    │    └─BatchNorm2d (bn2)            [32, 128, 28, 28]                                            [32, 128, 28, 28]                                            256                                                          True
# │    │    └─Sequential (downsample)      [32, 64, 56, 56]                                             [32, 128, 28, 28]                                            8,448                                                        True
# │    │    └─ReLU (relu)                  [32, 128, 28, 28]                                            [32, 128, 28, 28]                                            --                                                           --
# │    └─BasicBlock (1)                    [32, 128, 28, 28]                                            [32, 128, 28, 28]                                            --                                                           True
# │    │    └─Conv2d (conv1)               [32, 128, 28, 28]                                            [32, 128, 28, 28]                                            147,456                                                      True
# │    │    └─BatchNorm2d (bn1)            [32, 128, 28, 28]                                            [32, 128, 28, 28]                                            256                                                          True
# │    │    └─ReLU (relu)                  [32, 128, 28, 28]                                            [32, 128, 28, 28]                                            --                                                           --
# │    │    └─Conv2d (conv2)               [32, 128, 28, 28]                                            [32, 128, 28, 28]                                            147,456                                                      True
# │    │    └─BatchNorm2d (bn2)            [32, 128, 28, 28]                                            [32, 128, 28, 28]                                            256                                                          True
# │    │    └─ReLU (relu)                  [32, 128, 28, 28]                                            [32, 128, 28, 28]                                            --                                                           --
# ├─Sequential (layer3)                    [32, 128, 28, 28]                                            [32, 256, 14, 14]                                            --                                                           True
# │    └─BasicBlock (0)                    [32, 128, 28, 28]                                            [32, 256, 14, 14]                                            --                                                           True
# │    │    └─Conv2d (conv1)               [32, 128, 28, 28]                                            [32, 256, 14, 14]                                            294,912                                                      True
# │    │    └─BatchNorm2d (bn1)            [32, 256, 14, 14]                                            [32, 256, 14, 14]                                            512                                                          True
# │    │    └─ReLU (relu)                  [32, 256, 14, 14]                                            [32, 256, 14, 14]                                            --                                                           --
# │    │    └─Conv2d (conv2)               [32, 256, 14, 14]                                            [32, 256, 14, 14]                                            589,824                                                      True
# │    │    └─BatchNorm2d (bn2)            [32, 256, 14, 14]                                            [32, 256, 14, 14]                                            512                                                          True
# │    │    └─Sequential (downsample)      [32, 128, 28, 28]                                            [32, 256, 14, 14]                                            33,280                                                       True
# │    │    └─ReLU (relu)                  [32, 256, 14, 14]                                            [32, 256, 14, 14]                                            --                                                           --
# │    └─BasicBlock (1)                    [32, 256, 14, 14]                                            [32, 256, 14, 14]                                            --                                                           True
# │    │    └─Conv2d (conv1)               [32, 256, 14, 14]                                            [32, 256, 14, 14]                                            589,824                                                      True
# │    │    └─BatchNorm2d (bn1)            [32, 256, 14, 14]                                            [32, 256, 14, 14]                                            512                                                          True
# │    │    └─ReLU (relu)                  [32, 256, 14, 14]                                            [32, 256, 14, 14]                                            --                                                           --
# │    │    └─Conv2d (conv2)               [32, 256, 14, 14]                                            [32, 256, 14, 14]                                            589,824                                                      True
# │    │    └─BatchNorm2d (bn2)            [32, 256, 14, 14]                                            [32, 256, 14, 14]                                            512                                                          True
# │    │    └─ReLU (relu)                  [32, 256, 14, 14]                                            [32, 256, 14, 14]                                            --                                                           --
# ├─Sequential (layer4)                    [32, 256, 14, 14]                                            [32, 512, 7, 7]                                              --                                                           True
# │    └─BasicBlock (0)                    [32, 256, 14, 14]                                            [32, 512, 7, 7]                                              --                                                           True
# │    │    └─Conv2d (conv1)               [32, 256, 14, 14]                                            [32, 512, 7, 7]                                              1,179,648                                                    True
# │    │    └─BatchNorm2d (bn1)            [32, 512, 7, 7]                                              [32, 512, 7, 7]                                              1,024                                                        True
# │    │    └─ReLU (relu)                  [32, 512, 7, 7]                                              [32, 512, 7, 7]                                              --                                                           --
# │    │    └─Conv2d (conv2)               [32, 512, 7, 7]                                              [32, 512, 7, 7]                                              2,359,296                                                    True
# │    │    └─BatchNorm2d (bn2)            [32, 512, 7, 7]                                              [32, 512, 7, 7]                                              1,024                                                        True
# │    │    └─Sequential (downsample)      [32, 256, 14, 14]                                            [32, 512, 7, 7]                                              132,096                                                      True
# │    │    └─ReLU (relu)                  [32, 512, 7, 7]                                              [32, 512, 7, 7]                                              --                                                           --
# │    └─BasicBlock (1)                    [32, 512, 7, 7]                                              [32, 512, 7, 7]                                              --                                                           True
# │    │    └─Conv2d (conv1)               [32, 512, 7, 7]                                              [32, 512, 7, 7]                                              2,359,296                                                    True
# │    │    └─BatchNorm2d (bn1)            [32, 512, 7, 7]                                              [32, 512, 7, 7]                                              1,024                                                        True
# │    │    └─ReLU (relu)                  [32, 512, 7, 7]                                              [32, 512, 7, 7]                                              --                                                           --
# │    │    └─Conv2d (conv2)               [32, 512, 7, 7]                                              [32, 512, 7, 7]                                              2,359,296                                                    True
# │    │    └─BatchNorm2d (bn2)            [32, 512, 7, 7]                                              [32, 512, 7, 7]                                              1,024                                                        True
# │    │    └─ReLU (relu)                  [32, 512, 7, 7]                                              [32, 512, 7, 7]                                              --                                                           --
# ├─AdaptiveAvgPool2d (avgpool)            [32, 512, 7, 7]                                              [32, 512, 1, 1]                                              --                                                           --
# ├─Linear (fc)                            [32, 512]                                                    [32, 10]                                                     5,130                                                        True
# ========================================================================================================================================================================================================================================================================================
# Total params: 11,181,642
# Trainable params: 11,181,642
# Non-trainable params: 0
# Total mult-adds (G): 58.03
# ========================================================================================================================================================================================================================================================================================
# Input size (MB): 19.27
# Forward/backward pass size (MB): 1271.66
# Params size (MB): 44.73
# Estimated Total Size (MB): 1335.66
# ========================================================================================================================================================================================================================================================================================

# %%
loss_fn = nn.CrossEntropyLoss()
if config.optimiser == "SGD":
    optimiser = torch.optim.SGD(resnet_model.parameters(), lr=config.learning_rate)
elif config.optimiser == "ADAM":
    optimiser = torch.optim.Adam(resnet_model.parameters(), lr=config.learning_rate)

# %%
# metrics definition
accuracy_metric = torchmetrics.Accuracy(task="multiclass", num_classes=10)

# %%
# monitor parameter values i.e weights and biases and model gradients
wandb.watch(resnet_model, criterion=loss_fn, log="all")
# Out:
# []

# %%
def train_model(model, dataloader: torch.utils.data.DataLoader):
    """
    
    """
    train_acc, train_loss = 0, 0
    model.train()
    for batch_data, batch_label in train_dataloader:
        batch_data = batch_data.to(DEVICE)
        batch_label = batch_label.to(DEVICE)\

        pred_logits = model(batch_data)

        train_batch_loss = loss_fn(pred_logits, batch_label)
        train_loss += train_batch_loss

        preds = nn.functional.softmax(pred_logits, dim=0).argmax(dim=1)
        
        train_batch_acc = accuracy_metric(preds.cpu(), batch_label.cpu()) * 100
        train_acc += train_batch_acc

        optimiser.zero_grad()

        train_batch_loss.backward()

        optimiser.step()
    
    # average of metrics per batch
    train_acc /= len(train_dataloader)
    train_loss /= len(train_dataloader)

    return train_loss, train_acc

# %%
def test_model(model, dataloader: torch.utils.data.DataLoader):
    """
    
    """
    test_loss, test_acc =  0, 0
    model.eval() # set model to evaluation mode
    with torch.inference_mode():
        for test_batch_data, test_batch_label in dataloader:

            test_batch_data = test_batch_data.to(DEVICE)
            test_batch_label = test_batch_label.to(DEVICE)

            pred_logits = model(test_batch_data)

            test_batch_loss = loss_fn(pred_logits, test_batch_label)
            test_loss += test_batch_loss

            preds = nn.functional.softmax(pred_logits, dim=0).argmax(dim=1)
            
            batch_acc = accuracy_metric(preds.cpu(), test_batch_label.cpu()) * 100
            test_acc += batch_acc
        
        # average of loss metrics
        test_loss /= len(test_dataloader)
        test_acc /= len(test_dataloader)
    return test_loss, test_acc

# %%
def model_prediction(model, dataloader: torch.utils.data.DataLoader):
    """
    
    """
    all_preds = []
    model.to(DEVICE)
    model.eval() # set model to evaluation mode
    with torch.inference_mode():
        for test_batch_data, test_batch_label in dataloader:

            test_batch_data = test_batch_data.to(DEVICE)
            test_batch_label = test_batch_label.to(DEVICE)

            pred_logits = model(test_batch_data)
            preds = nn.functional.softmax(pred_logits, dim=0).argmax(dim=1)
            
            all_preds.append(preds.to("cpu"))
        
    all_preds_tensor = torch.cat(all_preds)
    return all_preds_tensor

# %% [markdown]
# ##### Model Training

# %%
for epoch in tqdm(range(config.epochs)):

    # MODEL TRAINING
    train_loss, train_accuracy = train_model(resnet_model, train_dataloader)

    # MODEL EVALUATION
    test_loss, test_accuracy = test_model(resnet_model, test_dataloader)
    
    # print training metrics
    print(f"Epoch: {epoch}")
    print(f"Training loss: {train_loss: .3f}\t Training accuracy: {train_accuracy: .3f}", end="\t")
    print(f"Test loss: {test_loss: .3f}\t Test acc: {test_accuracy: .3f}")

    # log epoch metrics to WandB
    epoch_log_dict = {
        "training_accuracy": train_accuracy,
        "training_loss": train_loss,
        "test_loss": test_loss,
        "test_accuracy": test_accuracy
    }
    wandb.log(epoch_log_dict)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# Epoch: 0
# Training loss:  1.905	 Training accuracy:  31.884	Test loss:  1.883	 Test acc:  35.853
# Epoch: 1
# Training loss:  1.616	 Training accuracy:  41.183	Test loss:  1.579	 Test acc:  41.723
# Epoch: 2
# Training loss:  1.429	 Training accuracy:  46.241	Test loss:  1.501	 Test acc:  46.036
# Epoch: 3
# Training loss:  1.262	 Training accuracy:  50.510	Test loss:  1.299	 Test acc:  51.757
# Epoch: 4
# Training loss:  1.126	 Training accuracy:  54.083	Test loss:  1.055	 Test acc:  55.002
# Epoch: 5
# Training loss:  1.028	 Training accuracy:  55.888	Test loss:  1.170	 Test acc:  55.042
# Epoch: 6
# Training loss:  0.950	 Training accuracy:  57.835	Test loss:  0.951	 Test acc:  58.277
# Epoch: 7
# Training loss:  0.886	 Training accuracy:  58.983	Test loss:  0.952	 Test acc:  57.987
# Epoch: 8
# Training loss:  0.831	 Training accuracy:  60.169	Test loss:  0.865	 Test acc:  58.756
# Epoch: 10
# Training loss:  0.741	 Training accuracy:  61.902	Test loss:  0.810	 Test acc:  60.064
# Epoch: 11
# Training loss:  0.702	 Training accuracy:  62.038	Test loss:  0.787	 Test acc:  60.284
# Epoch: 12
# Training loss:  0.668	 Training accuracy:  62.644	Test loss:  0.759	 Test acc:  60.952
# Epoch: 13
# Training loss:  0.637	 Training accuracy:  63.266	Test loss:  0.725	 Test acc:  61.442
# Epoch: 14
# Training loss:  0.609	 Training accuracy:  63.622	Test loss:  0.714	 Test acc:  63.229
# Epoch: 15
# Training loss:  0.581	 Training accuracy:  64.739	Test loss:  0.674	 Test acc:  61.961
# Epoch: 16
# Training loss:  0.557	 Training accuracy:  65.095	Test loss:  0.683	 Test acc:  62.570
# Epoch: 17
# Training loss:  0.531	 Training accuracy:  65.613	Test loss:  0.720	 Test acc:  62.001
# Epoch: 18
# Training loss:  0.516	 Training accuracy:  65.829	Test loss:  0.608	 Test acc:  64.058
# Epoch: 19
# Training loss:  0.492	 Training accuracy:  65.781	Test loss:  0.639	 Test acc:  62.750
# Epoch: 20
# Training loss:  0.477	 Training accuracy:  66.813	Test loss:  0.572	 Test acc:  64.407
# Epoch: 21
# Training loss:  0.463	 Training accuracy:  66.645	Test loss:  0.645	 Test acc:  61.152
# Epoch: 22
# Training loss:  0.445	 Training accuracy:  66.805	Test loss:  0.622	 Test acc:  64.167
# Epoch: 23
# Training loss:  0.430	 Training accuracy:  67.051	Test loss:  0.579	 Test acc:  63.798
# Epoch: 24
# Training loss:  0.410	 Training accuracy:  67.726	Test loss:  0.579	 Test acc:  64.437
# Epoch: 25
# Training loss:  0.394	 Training accuracy:  67.616	Test loss:  0.625	 Test acc:  63.838
# Epoch: 26
# Training loss:  0.384	 Training accuracy:  68.124	Test loss:  0.531	 Test acc:  64.487
# Epoch: 27
# Training loss:  0.371	 Training accuracy:  68.478	Test loss:  0.566	 Test acc:  64.407
# Epoch: 28
# Training loss:  0.361	 Training accuracy:  69.056	Test loss:  0.516	 Test acc:  65.246
# Epoch: 29
# Training loss:  0.347	 Training accuracy:  68.966	Test loss:  0.539	 Test acc:  64.906

# %% [markdown]
# ## Visualisations

# %% [markdown]
# #### Model accuracy and loss

# %%
# show logged metrics
# %wandb mustious/ECS795P_Classic
# Out:
# <iframe src='https://wandb.ai/mustious/ECS795P_Classic/workspace?jupyter=true' style='border:none;width:100%;height:420px;'></iframe>

# %% [markdown]
# #### Sample Images of Predicted Classes

# %%
predicted_images_fig = display_predicted_images(resnet_model, test_dataloader, class_labels=class_labels, figsize=(15,10))
plt.savefig(f"{config.architecture}_sample_model_prediction.jpg")
plt.show()

# log prediction image in wandb
wandb.log({"sample_predictions": predicted_images_fig})

# %% [markdown]
# #### Confusion Matrix Visualisation

# %%
predictions = model_prediction(resnet_model, test_dataloader)

confusion_matrix = torchmetrics.ConfusionMatrix(task="multiclass", num_classes=len(class_labels))
confusion_matrix_tensor = confusion_matrix(predictions, torch.Tensor(test_data.targets))
confusion_matrix_fig, ax = plot_confusion_matrix(
    confusion_matrix_tensor.numpy(),
    class_names= class_labels,
    figsize=(10, 7))
plt.show()

# log prediction image in wandb
wandb.log({"confusion_matrix": confusion_matrix_fig})
